# %% [markdown]
# # 7000LBSBAI - Programming for Business Analytics
# ## Week 1 - Task 1: Google Colab Setup Exercise
#
# ---
#
# **Module:** Programming for Business Analytics
# **Week:** 1
# **Time:** 20 minutes
# **Topics covered:** Google Colab · Notebooks · Python code introduction
#
# ---

# %% [markdown]
# ## 1. Open Google Colab: https://colab.research.google.com

# %% [markdown]
# ---
#
# ## 2. Create Google Account, or login to your existing Google account

# %% [markdown]
# ---
# ## 3. Create new Notebook
#
# File -> **New notebook in Drive**
#
# > Rename the notebook to **'Week1_Introduction.ipynb'**

# %% [markdown]
# ---
#
# ## 4. Turn off AI suggestions
#
# To improve your learning experience, you will need to prevent Google Colab from trying to autocomplete your code using AI.
#
# You will need to complete this step for EVERY notebook:
#
# Go to **Tools** -> **Settings** -> **AI Assistance**
#
# > Uncheck `☐ Show AI-powered inline completions`
#
# > Check `☑️ Hide generative AI features`
#
# ![alt text](https://drive.google.com/uc?id=1ZuLS8zMNhWRsqK1ube6-aIAR4fsIJhWM)

# %% [markdown]
# ---
# ## 5. Now you are ready to run your first bit of Python Code!
#
# In the first cell, type the following code:
#
# ```python
# # My first bit of Python code!
#
# print("Hello Business Analytics!")
# ```
# > To run the code in a cell: click on it and press Ctrl + Enter (or click the ▶ button on the left).
#
# It should display the text **Hello Business Analytics!** below your code
#
# 📝 Tip: If you see an error, read it carefully — it usually tells you exactly what went wrong. Don't worry about errors; they are a normal part of programming.

# %%
# My first bit of Python code!

print("Hello Business Analytics!")
# Out:
# Hello Business Analytics!

# %% [markdown]
# ---
# ## 6. Create another code cell and create your first variable 'name' , make this your name, then display it.
#
# Hover over the bottom of your first code cell and click `+ Code` to create a new code cell.
#
# > Type the following code into the new code cell (Use your own first name within the "" instead of XXXXXX):
#
# ```python
# # Creating a new variable 'name'
#
# name = "XXXXXX"
#
# print(name)
# ```
#
# > Run the code ▶

# %%
# Creating a new variable 'name'

name = "Michelle" # Put your own name here!

print(name)
# Out:
# Michelle

# %% [markdown]
# 📝 **IMPORTANT! Your work is currently in the Google Colab cloud so should autosave as you work. However, it is also a good idea to periodically manually save your work so that you do not lose it.**

# %% [markdown]
# ---
# ## 7. Save your notebook to your Google Drive.
#
# > File -> **Save**

# %% [markdown]
# ---
# ## 8. Download your Notebook and Save it to your university OneDrive.
#
# Go to: File -> **Download** -> **Download .ipynb**
#
# > 📝 Tip: `.ipynb` is the file suffix for Notebook files. They can only be opened in a Jupyter Notebook service such as Google Colab
#
# 📁 Navigate to the **Downloads** folder on your PC
#
# ![alt text](https://drive.google.com/uc?id=1Hj21-eYwoV-b4rM1zXjgVz6vZmX1hqtE)
#
# Move the **.ipynb** file you have just downloaded from Downloads to your university OneDrive folder (it is recommended that you create a separate folder for your work on this module).
#
# ![alt text](https://drive.google.com/uc?id=10YMBoe7HJRloMpAkScUAmjfrVIclSPX5)
#
# > 📝 Tip: **It will be important to save a copy of your work in this way for your weekly tasks and final assignment.**

# %% [markdown]
# ---
# ## 9. Close this notebook.
#
# Find it in Google Drive and reopen it again.
#
# > Confirm that your work is still available and working correctly.
#
# ---

# %% [markdown]
# ## 10. Final Task: Open a Notebook from GitHub and Save it to Google Drive
#
# Go back to [Google Colab](https://colab.research.google.com/) in your browser
#
# > Go to **Upload notebook**
#
# > Click the **GitHub** tab along the side of the dialog box
#
# In the search box, type the repository name:
#
# ```
# 7000lbsbai
# ```
#
# > Press **Enter** or click the 🔍 icon to search
#
# ![alt text](https://drive.google.com/uc?id=1e5lmV15u0jFvNQWw2sQAwBEgtCTJP61Y)
#
# A list of notebook files will appear below the search box.
#
# > Find and click on **"Week1_Task1_Colab_Setup_Exercise.ipynb"**
#
# The notebook will open in a new Colab tab. ⚠️ **At this point you are only viewing a temporary copy** — it is not yet saved anywhere, and any changes you make now could be lost.
#
# > Go to **File** -> **Save a copy in Drive**
#
# A new tab will open showing your own editable copy of the notebook (named something like "Copy of Week1_Task1_Colab_Setup_Exercise.ipynb").
#
# **Rename** the Notebook by adding your name to the filename.
#
# **Save** it (File -> Save)
#
# > 📝 Tip: **This is how you will open and work on the Notebooks provided via GitHub each week. Always remember to "Save a copy in Drive" before you start working — otherwise your changes won't be saved.** You can then close the original temporary tab and continue working in your own renamed copy.
#
# Finally, close your copy of this notebook then check if you can find it in Google Drive and open it again.
